# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import hydra
from hydra.utils import instantiate
from hydra import compose, initialize
from omegaconf import OmegaConf
import torchaudio, torch
import matplotlib.pyplot as plt
import sys
from torchvision.transforms import Resize
sys.path.append("..")

# %%
with initialize("../configs/"):
    cfg = compose(config_name="train", overrides=["original_work_dir=\"./\"",\
        "data_dir=\"./data/\""])
    print(OmegaConf.to_yaml(cfg))
# Out:
# original_work_dir: ./
# data_dir: ./data/
# print_config: true
# ignore_warnings: true
# train: true
# test: false
# seed: null
# name: default
# audio:
#   transform:
#     sample_rate: 32000
#     n_fft: 1024
#     win_length: 1024
#     hop_length: 512
#     f_min: 0.0
#     f_max: 16000.0
#     n_mels: 128
#     window_fn:
#       _target_: hydra.utils.get_method
#       path: torch.hann_window
#     spec_time_steps: 300
# datamodule:
#   dataset: FSD50K
#   num_classes: 200
#   batch_size: 64
#   num_workers: 0
#   pin_memory: false
#   training_dataset:
#     _target_: src.datamodules.components.datasets.FSD50K
#     audio_cfg: ${audio}
#     augum_cfg:
#       time_domain: None
#       frequency_domain:
#         toTensor:
#           _target_: torchvision.transforms.ToTensor
#     data_dir: ${data_dir}
#     prog_resize: None
#     res_p: 0.0
#     mode: train
#   validation_dataset:
#     _target_: src.datamodules.components.datasets.FSD50K
#     audio_cfg: ${audio}
# ...

# %% [markdown]
# # Callbacks testing

# %%
from src.utils.callbacks import Progressive_training

# %%
instantiate(cfg.callbacks.progressive_resize,  _recursive_=False)

# %% [markdown]
# # Metrics testing

# %%
from torchmetrics import Accuracy

# %% [markdown]
# # Dataset testing

# %%
from src.datamodules.components import datasets

# %%
type(cfg.callbacks.progressive_resize.optimizer)
# Out:
# omegaconf.dictconfig.DictConfig

# %%
instantiate(cfg.trainer)
# Out:
# GPU available: True, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# c:\Users\fcolc\anaconda3\lib\site-packages\pytorch_lightning\trainer\trainer.py:1812: PossibleUserWarning: GPU available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='gpu', devices=1)`.
#   rank_zero_warn(

# %%
cfg.trainer
# Out:
# {'_target_': 'pytorch_lightning.Trainer', 'gpus': 0, 'min_epochs': 1, 'max_epochs': 10, 'resume_from_checkpoint': None}

# %%
import csv

# %%
with open("D:\FSD50K\FSD50K.ground_truth\dev.csv", mode='r') as infile:
    reader = csv.reader(infile)
    mydict = {rows[0]:rows[1] for rows in reader}
mydict
# Out:
# {'fname': 'labels',
#  '64760': 'Electric_guitar,Guitar,Plucked_string_instrument,Musical_instrument,Music',
#  '16399': 'Electric_guitar,Guitar,Plucked_string_instrument,Musical_instrument,Music',
#  '16401': 'Electric_guitar,Guitar,Plucked_string_instrument,Musical_instrument,Music',
#  '16402': 'Electric_guitar,Guitar,Plucked_string_instrument,Musical_instrument,Music',
#  '16404': 'Electric_guitar,Guitar,Plucked_string_instrument,Musical_instrument,Music',
#  '345111': 'Electric_guitar,Guitar,Plucked_string_instrument,Musical_instrument,Music',
#  '64761': 'Electric_guitar,Guitar,Plucked_string_instrument,Musical_instrument,Music',
#  '268259': 'Electric_guitar,Guitar,Plucked_string_instrument,Musical_instrument,Music',
#  '64762': 'Electric_guitar,Guitar,Plucked_string_instrument,Musical_instrument,Music',
#  '160826': 'Electric_guitar,Guitar,Plucked_string_instrument,Musical_instrument,Music',
# ...

# %%
with open("D:\FSD50K\FSD50K.ground_truth\\vocabulary.csv", mode='r') as infile:
    reader = csv.reader(infile)
    mydict = {rows[1]:rows[0] for rows in reader}
len(mydict)
# Out:
# 200

# %%
import torch

a = [0, 1, 3, 4]
b = torch.zeros((120))

# %%
b[a] = 1

# %%
b[a]
# Out:
# tensor([1., 1., 1., 1.])
